# %% [markdown]
# The Virtual environment is activated for this model and then then a command should be run that creates the numpy files with the depth value of each pixel and this notebook then prints the depth map

# %%
# %python run.py \
     --input_rgb_dir input/in-the-wild_example \
     --output_dir output/in-the-wild_example_lcm

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the .npy file
depth_map = np.load('output/depth_npy/class_pred.npy')
print(depth_map)
plt.imshow(depth_map, cmap='inferno')  # You can use 'gray', 'hot', 'viridis', etc.
plt.colorbar(label='Depth Value in meters')
plt.title('Depth Map Visualization')
plt.show()
# Out:
# [[0.5038709  0.5038709  0.5038709  ... 0.08818029 0.08818029 0.08818029]
#  [0.5038709  0.5038709  0.5038709  ... 0.08818029 0.08818029 0.08818029]
#  [0.5038709  0.5038709  0.5038709  ... 0.08818029 0.08818029 0.08818029]
#  ...
#  [0.4137317  0.4137317  0.4137317  ... 0.11322418 0.11322418 0.11322418]
#  [0.4137317  0.4137317  0.4137317  ... 0.11322418 0.11322418 0.11322418]
#  [0.4137317  0.4137317  0.4137317  ... 0.11322418 0.11322418 0.11322418]]
